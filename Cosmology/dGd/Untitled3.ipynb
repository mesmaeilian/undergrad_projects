# %%
# def f_loader(z, mu, alpha, beta, form):
#     if form == 'pko':
#         file_name = '/Users/Muhammad/Desktop/p_obs_data1/' + "%s"% z+ sepr + "%s"%mu + sepr + "%s"%alpha + sepr + "%s"%beta + '.dat' 
#         try:
#             file = np.loadtxt(file_name)
#             return file
#         except Exception as e:
#             return e
#     else:
#         directory = '/Users/Muhammad/Desktop/p_obs_data2/'
#         file_name = directory +  "%s"%z + sepr + "%s"%alpha + sepr + "%s"%beta + '.dat' 
#         try:
#             file = np.loadtxt(file_name)
#             return file
#         except Exception as e:
#             return e

        
# def p_val(k, z, mu, alpha, beta, form):
#     try :
#         file = f_loader(z, mu, alpha, beta, form)
#         index = np.where(file[0] == k)[0][0]
# #         print(index)
#         return file[1][index]
#     except Exception as e:
#         print(str(e))
    
# def derivit(k, z, alpha, beta, cofa):
#     if cofa == 'alpha':
#         file1 = f_loader(z, 0, alpha, beta, 'pk')
#         file2 = f_loader(z, 0, alpha + 0.0001, beta, 'pk')
#         index = np.where(file1[0] == k)[0][0]
# #         print(index)
#         p1 = file1[1][index]
#         p2 = file2[1][index]
#         return (p2 - p1) / 0.0001
#     else:
#         file1 = f_loader(z, 0, alpha, beta, 'pk')
#         file2 = f_loader(z, 0, alpha, beta + 0.0001, 'pk')
#         index = np.where(file1[0] == k)[0][0]
# #         print(index)
#         p1 = file1[1][index]
#         p2 = file2[1][index]
#         return (p2 - p1) / 0.0001


# def dk_cal(kh, lst):
#     res = []
#     for i, j in enumerate(kh[:113]):
#         dk = kh[i+1] - kh[i]
#         val = lst[i]*dk
#         res.append(val)
#     return res

# %%
# alpha = np.arange(alpha_min, alpha_max+0.001, 0.01)
# beta = np.arange(beta_min, beta_max+0.00001, 0.0001)
 
# sepr = '..'
# def file_gen():
#     alpha = 0.008
#     beta = 0.002
#     for p in mu:
#         for q in z:
#             file_name = '/Users/Muhammad/Desktop/p_obs_data1/' + str(q + 0.001)[0:4] + sepr + str(p)[0:4] + sepr + '0.008' + sepr + '0.002' + '.dat'
#             print(file_name)
#             kh, pk = P_obs(q, p, alpha, beta)
#             np.savetxt(file_name, [kh, pk])
# # file_gen() 

# def file_gen2():
#     alpha = [0.008, 0.0081]
#     beta = [0.002, 0.0021]
#     for i in alpha:
#         for j in beta:
#             for q in z:
#                 file_name = '/Users/Muhammad/Desktop/p_obs_data2/' + str(q + 0.0001)[0:4] + sepr +  str(i) + sepr + str(j) + '.dat'
#                 print(file_name)
#                 kh, pk = P_k(q, i, j)
#                 np.savetxt(file_name, [kh, pk[0]])
                
# # file_gen2()
